# %%
import os
import pandas as pd
from trulens.apps.virtual import VirtualApp, TruVirtual
from trulens.connectors.snowflake import SnowflakeConnector
from trulens.core import TruSession, Feedback


from snowflake.snowpark import Session
import toml

# %%
#Update your path to point to the config.toml file for your snowflake connection
config = toml.load('~/.../config.toml').get('connections').get('default_connection')

#Update to your database and schema used in the trulens cortex analyst app
config['database']= 'DB'
config['schema']= 'SCHEMA'

conn = SnowflakeConnector(**config)
session = TruSession(connector=conn)
# Out:
# 🦑 Initialized with db url snowflake://ebotwick:***@sfsenorthamerica-demo-ebotwick/A_NFL_RAG/PUBLIC?port=443&protocol=https&role=ACCOUNTADMIN&warehouse=DEFAULT_XS .
# 🛑 Secret keys may be written to the database. See the `database_redact_keys` option of `TruSession` to prevent this.
# Set TruLens workspace version tag: [('Statement executed successfully.',)]

# %%
session.get_leaderboard()
# Out:
#                                    Conciseness  Final Answer Relevance  \
# app_name           app_version
# CORTEX_ANALYST     test_v4            0.955556                     NaN
#                    test_v3            0.466667                     NaN
# CORTEX_ANALYST_APP llama3.1-70b            NaN                1.000000
#                    mistral-large2          NaN                0.833333
# CORTEX_ANALYST     test_v5                 NaN                     NaN
#
#                                    Interpretation Accuracy  SQL relevance  \
# app_name           app_version
# CORTEX_ANALYST     test_v4                             NaN            NaN
#                    test_v3                             NaN            NaN
# CORTEX_ANALYST_APP llama3.1-70b                   1.000000        1.00000
#                    mistral-large2                 0.895833        0.97619
# CORTEX_ANALYST     test_v5                             NaN            NaN
#
# ...

# %%
## Optionally migrate database as needed if package versions have changed
# session.migrate_database()

# %%
from trulens.dashboard import run_dashboard, stop_dashboard, run_dashboard_sis
#Run local streamlit dashboard
run_dashboard()
# Out:
# Starting dashboard ...
# Accordion(children=(VBox(children=(VBox(children=(Label(value='STDOUT'), Output())), VBox(children=(Label(valu…
# Dashboard started at http://localhost:50843 .
# <Popen: returncode: None args: ['streamlit', 'run', '--server.headless=True'...>

# %%
#Create long-lived streamlit-in-Snowflake dashboard (will create in schema used in tru_session)
run_dashboard_sis(streamlit_name = 'TRULENS_DASHBOARD_SIS')
# Out:
# 'Streamlit TEST_TRU_DASH2 successfully created.'

# %%
#can use session object to programatically fetch data for apps/records/feedbacks etc.
tru_apps = pd.DataFrame(session.get_apps())
tru_apps
# Out:
#                                       tru_class_info  \
# 0  {'name': 'TruCustomApp', 'module': {'package_n...
# 1  {'name': 'TruCustomApp', 'module': {'package_n...
# 2  {'name': 'TruCustomApp', 'module': {'package_n...
# 3  {'name': 'TruCustomApp', 'module': {'package_n...
# 4  {'name': 'TruCustomApp', 'module': {'package_n...
#
#                                       app_id  \
# 0  app_hash_7c0cb1164f80515367486b1a206cdca6
# 1  app_hash_93dffc4aae1d09bfc16546ec127ae96d
# 2  app_hash_62ab4b33d631ad85109eff69e875b6b5
# 3  app_hash_a5863e03da08f631cef67669f4091e00
# 4  app_hash_cac2a804f181954358f5cd5a1f8ec609
#
#                                app_name  \
# 0                        CORTEX_ANALYST
# 1                        CORTEX_ANALYST
# 2  CORTEX_ANALYST_WITH_AI_OBSERVABILITY
# 3                    CORTEX_ANALYST_APP
# 4                    CORTEX_ANALYST_APP
#
#                              app_version tags metadata  \
# 0  sql_and_summarization_multi_agent_app    -       {}
# ...
